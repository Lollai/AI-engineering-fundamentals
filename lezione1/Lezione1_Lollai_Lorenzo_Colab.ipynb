# %% [markdown]
# <a href="https://colab.research.google.com/github/marcouras/AI-engineering-fundamentals/blob/main/lezione1/Lezione1_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
#
# ---
#
# # 🤖 AI Engineering Fundamentals
# ## Lezione 1 — Setup & Fondamenta
#
# **ITS Novitas 4.0 — Sviluppatore Intelligenza Artificiale**
# Docente: Marco Uras | 📅 Martedì 19/05/2026
#
# ---
#
# ### 📋 Istruzioni per iniziare
#
# 1. **Salva una copia** di questo notebook nel tuo Google Drive:
#    `File → Salva una copia in Drive`
#
# 2. **Aggiungi la API key** nei Colab Secrets (vedi cella qui sotto)
#
# 3. **Esegui le celle** dall'alto verso il basso con `Shift+Invio`
#
# 4. **Al termine**, scarica il notebook completato e caricalo nel tuo GitHub:
#    `File → Scarica → Scarica .ipynb`
#
# ---
#
# ### 🎯 Obiettivi di oggi
# - ✅ Fare la prima chiamata all'API di Claude
# - ✅ Capire i parametri fondamentali: `model`, `temperature`, `system`
# - ✅ Completare i 4 esercizi
# - ✅ Caricare il notebook completato su GitHub

# %% [markdown]
# ---
# ## Dove trovo la mia API Key?
#
# Vai su [console.anthropic.com](https://console.anthropic.com), poi:
#
# 1. Accedi con il tuo account
# 2. Nel menu a sinistra clicca **"API Keys"**
# 3. Clicca **"Create Key"**
# 4. Dagli un nome (es. `ITS-Novitas-corso`)
# 5. **Copia subito la chiave — la vedi solo in quel momento**
#
# La chiave ha questa forma: `sk-ant-api03-...`
#
# ## 🔑 Step 1 — Configura la API Key
#
# Su Colab usiamo i **Secrets**
#
# ### Come aggiungere la chiave:
# 1. Clicca sull'icona 🔑 **lucchetto** nella barra sinistra di Colab
# 2. Clicca **"+ Aggiungi nuovo secret"**
# 3. **Nome:** `ANTHROPIC_API_KEY`
# 4. **Valore:** incolla la tua chiave `sk-ant-...`
# 5. Attiva il toggle **"Accesso al notebook"**
#
# > 💡 Lo fai una volta sola — il secret rimane salvato per tutti i tuoi notebook Colab.

# %%
# Installa la libreria Anthropic (necessario su Colab ad ogni sessione)
# !pip install anthropic -q
print("✅ Libreria installata!")
# Out:
# ✅ Libreria installata!

# %%
# Carica la API key dai Colab Secrets
from google.colab import userdata
import anthropic
import os

# Legge il secret che hai configurato
os.environ["ANTHROPIC_API_KEY"] = userdata.get("ANTHROPIC_API_KEY")

# Crea il client
client = anthropic.Anthropic()

# Verifica (senza stampare la chiave!)
key = os.environ.get("ANTHROPIC_API_KEY", "")
if key.startswith("sk-ant"):
    print(f"✅ API key configurata correttamente: sk-ant-...{key[-6:]}")
else:
    print("❌ API key non trovata. Controlla i Colab Secrets.")
# Out:
# ✅ API key configurata correttamente: sk-ant-...jU4AAA

# %% [markdown]
# ---
# ## 🚀 Step 2 — La prima chiamata all'API
#
# Questo è il codice più importante del corso. Leggi ogni riga con attenzione prima di eseguire.

# %%
# La prima chiamata a Claude
message = client.messages.create(
    model="claude-haiku-4-5-20251001",   # modello veloce per esercizi
    max_tokens=1024,
    messages=[
        {
            "role": "user",
            "content": "Ciao! Presentati in 2 righe e dimmi cosa puoi fare per me."
        }
    ]
)

print("=" * 50)
print("RISPOSTA DI CLAUDE:")
print("=" * 50)
print(message.content[0].text)
# Out:
# ==================================================
# RISPOSTA DI CLAUDE:
# ==================================================
# # Ciao! 👋
#
# Sono Claude, un assistente AI creato da Anthropic. Posso aiutarti con scrittura, analisi, coding, brainstorming, spiegazioni, tradurzioni, problem-solving e tanto altro—basta che tu mi chieda!

# %%
# Esploriamo la struttura completa della risposta
print("📊 Dettagli della risposta:")
print(f"  Modello usato:     {message.model}")
print(f"  Stop reason:       {message.stop_reason}")
print(f"  Token in input:    {message.usage.input_tokens}")
print(f"  Token in output:   {message.usage.output_tokens}")
print(f"  Token totali:      {message.usage.input_tokens + message.usage.output_tokens}")
# Out:
# 📊 Dettagli della risposta:
#   Modello usato:     claude-haiku-4-5-20251001
#   Stop reason:       end_turn
#   Token in input:    30
#   Token in output:   71
#   Token totali:      101

# %% [markdown]
# ---
# ## 🌡️ Step 3 — Il parametro `temperature`
#
# La `temperature` controlla quanto è variabile la risposta:
# - **0.0** → sempre la stessa risposta (codice, calcoli, fatti)
# - **0.7** → equilibrio (default consigliato)
# - **1.0** → molto creativo e variabile (scrittura creativa)

# %%
# Funzione helper — la useremo in tutti gli esercizi
def chiedi_claude(domanda, temperature=0.7, system=None, max_tokens=300):
    """Invia una domanda a Claude e restituisce la risposta testuale."""
    params = {
        "model": "claude-haiku-4-5-20251001",
        "max_tokens": max_tokens,
        "temperature": temperature,
        "messages": [{"role": "user", "content": domanda}]
    }
    if system:
        params["system"] = system

    response = client.messages.create(**params)
    return response.content[0].text

print("✅ Funzione helper pronta!")
# Out:
# ✅ Funzione helper pronta!

# %%
# Stessa domanda, temperature diverse


domanda = "completa questa frase con tre aggettivi particolari: il gatto è..."

print("🥶 temperature = 0.0 (deterministico):")
print(chiedi_claude(domanda, temperature=0.0))
print()
print("🥶 temperature = 0.0 (deterministico):")
print(chiedi_claude(domanda, temperature=0.0))
print()

print("🌡️  temperature = 0.7 (bilanciato):")
print(chiedi_claude(domanda, temperature=0.7))
print()
print("🌡️  temperature = 0.7 (bilanciato):")
print(chiedi_claude(domanda, temperature=0.7))
print()

print("🔥 temperature = 1.0 (creativo):")
print(chiedi_claude(domanda, temperature=1.0))
print()
print("🔥 temperature = 1.0 (creativo):")
print(chiedi_claude(domanda, temperature=1.0))
print()
# Out:
# 🥶 temperature = 0.0 (deterministico):
# # Il gatto è...
#
# **felino, enigmatico e indipendente**
#
# Oppure, se preferisci altre opzioni:
#
# - **sinuoso, misterioso e affettuoso**
# - **elegante, curioso e territoriale**
# - **agile, diffidente e affascinante**
#
# 🥶 temperature = 0.0 (deterministico):
# # Il gatto è...
#
# **felino, enigmatico e indipendente**
#
# Oppure, se preferisci altre opzioni:
#
# - **misterioso, elegante e affettuoso**
# - **agile, curioso e territoriale**
# - **silenzioso, astuto e affascinante**
#
# 🌡️  temperature = 0.7 (bilanciato):
# # Il gatto è...
#
# **felino, enigmatico e indipendente**
#
# Tre aggettivi che catturano l'essenza del gatto: la sua natura biologica, il suo carattere misterioso e la sua libertà di spirito.
#
# 🌡️  temperature = 0.7 (bilanciato):
# # Il gatto è...
#
# **vellutato, enigmatico e indipendente.**
#
# - **Vellutato**: per il suo pelo morbido e la natura delicata
# - **Enigmatico**: per lo sguardo misterioso e il comportamento imprevedibile
# - **Indipendente**: per la sua natura autonoma e il carattere libero
#
# 🔥 temperature = 1.0 (creativo):
# # Il gatto è...
#
# **felino, autonomo e enigmatico.**
#
# - **Felino** - rimanda alla natura selvaggia e elegante
# - **Autonomo** - sottolinea l'indipendenza caratteristica
# - **Enigmatico** - cattura il suo comportamento misterioso e affascinante
#
# 🔥 temperature = 1.0 (creativo):
# # Il gatto è...
#
# **felino, misterioso e affettuoso**
#
# - **Felino**: sottolinea la sua natura predatoria elegante
# - **Misterioso**: cattura quella qualità enigmatica nei suoi comportamenti
# - **Affettuoso**: evidenzia il legame che può creare con le persone

# %% [markdown]
# ---
# ## 🎭 Step 4 — Il `system` prompt
#
# Il system prompt definisce la **personalità** e il **comportamento** del chatbot.
# Stesso modello, system prompt diversi → comportamenti completamente diversi.

# %%
domanda = "Perchè il cielo è blu?"

print("👤 Senza system prompt:")
print(chiedi_claude(domanda))
print()

print("👩‍🏫 Insegnante per bambini delle elementari:")
print(chiedi_claude(domanda,
    system="Sei un insegnante per bambini di 8 anni. Spiega tutto con analogie del mondo reale, senza termini tecnici."))
print()

print("👨‍💻 Sviluppatore senior:")
print(chiedi_claude(domanda,
    system="Sei uno sviluppatore senior con 20 anni di esperienza. Rispondi in modo tecnico e diretto."))
# Out:
# 👤 Senza system prompt:
# # Perché il cielo è blu
#
# Il cielo appare blu principalmente per un fenomeno fisico chiamato **dispersione di Rayleigh**:
#
# ## Come funziona
#
# 1. **La luce del sole** è bianca, composta da tutti i colori dello spettro visibile
#
# 2. **Nell'atmosfera** la luce incontra molecole di azoto e ossigeno
#
# 3. **Le molecole disperdono** la luce blu e violetta molto più delle altre (la dispersione è inversamente proporzionale alla quarta potenza della lunghezza d'onda)
#
# 4. **Vediamo principalmente blu** perché:
#    - La luce blu ha lunghezza d'onda più corta
#    - La luce violetta, pur essendo dispersa più della blu, è in minore quantità nel sole e viene assorbita
#
# ## Variazioni
#
# - **All'alba/tramonto**: il cielo è rosso/arancione perché la luce percorre un percorso più lungo e il blu viene completamente disperso
# - **Di notte**: il cielo è nero perché non c'è luce solare
# - **Nello spazio**: il cielo è nero perché non c'è atmosfera per disperdere la luce
#
# 👩‍🏫 Insegnante per bambini delle elementari:
# # Perché il cielo è blu? 🌤️
#
# Immagina di avere una torcia magica che spara tanti colori diversi tutti insieme - come un arcobaleno che cammina!
#
# Quando questa luce (che viene dal Sole) arriva sulla Terra, incontra l'aria sopra la nostra testa. L'aria è piena di tante piccole particelle invisibili, come se fosse una stanza piena di palloncini microscopici.
#
# ## Ecco cosa succede:
#
# La luce **blu** è come una pallina piccola e leggera 🔵
# La luce **rossa** è come una pallina grande e pesante 🔴
#
# Quando le palline colpiscono i palloncini dell'aria:
# - Le palline **blu** piccole rimbalzano dappertutto e si sparpagliano in tutte le direzioni
# - Le palline **rosse** grandi vanno quasi dritte senza rimbalzare molto
#
# Siccome la luce blu rimbalza ovunque, arriva ai tuoi occhi da ogni parte del cielo. Per questo il cielo ti sembra **blu**!
#
# ## Un paragone:
# È come quando accendi una lampada in una stanza piena
#
# 👨‍💻 Sviluppatore senior:
# # Perché il cielo è blu
#
# La risposta tecnica è la **diffusione di Rayleigh**.
#
# ## Il meccanismo
#
# 1. **La luce solare** è composta da onde di diverse lunghezze d'onda (spettro visibile)
#
# 2. **Interazione con l'atmosfera**: quando la luce colpisce le molecole di aria (N₂, O₂) e particelle molto più piccole della lunghezza d'onda della luce, avviene una diffusione elastica
#
# 3. **Dipendenza dalla lunghezza d'onda**: l'intensità della diffusione di Rayleigh è inversamente proporzionale alla quarta potenza della lunghezza d'onda:
#
#    **I ∝ 1/λ⁴**
#
# ## Conseguenze
#
# - **Luce blu** (λ ≈ 450 nm): diffusa ~10 volte più della luce rossa (λ ≈ 700 nm)
# - La luce blu viene dispersa in tutte le direzioni
# - Il nostro occhio riceve questa luce diffusa da tutto il cielo
#
# ## Casi particolari
#
# - **Tramonto/alba**: la luce attraversa uno

# %% [markdown]
# ---
# ## ⭐ Esercizi
#
# > **Completa tutti e 4 gli esercizi, poi scarica il notebook e caricalo su GitHub.**
#
# Scrivi il tuo nome qui sotto prima di iniziare:

# %%
NOME_STUDENTE = "Lorenzo"  # ← SCRIVI IL TUO NOME QUI

if NOME_STUDENTE:
    print(f"✅ Notebook di: {NOME_STUDENTE}")
else:
    print("⚠️  Scrivi il tuo nome nella variabile NOME_STUDENTE!")
# Out:
# ✅ Notebook di: Lorenzo

# %% [markdown]
# ### Esercizio 1 — Base ★☆☆
# Chiedi a Claude qualcosa che ti interessa davvero — un consiglio, una spiegazione, una curiosità.

# %%
# Esercizio 1
miadomanda = "Dimmi due consigli pratici per studiare meglio l'intelligenza artificiale."
risposta = chiedi_claude(miadomanda)
print(risposta)
# Out:
# # Due consigli pratici per studiare l'IA
#
# ## 1. **Impara facendo, non solo leggendo**
# Non limitarti alla teoria. Usa piattaforme come:
# - **Google Colab** (gratuito, per Python)
# - **Hugging Face** (modelli pre-addestrati pronti all'uso)
# - **Kaggle** (dataset e competizioni)
#
# Inizia con progetti piccoli e concreti. Vedrai come funzionano davvero gli algoritmi.
#
# ## 2. **Costruisci una base matematica solida**
# L'IA si fonda su:
# - **Algebra lineare** (matrici, vettori)
# - **Probabilità e statistica**
# - **Calcolo** (derivate, gradienti)
#
# Non devi essere un matematico, ma capire questi fondamenti ti evita di "scatole nere" incomprensibili. Inizia con risorse visive e intuitive (3Blue1Brown su YouTube è eccellente).
#
# ---
#
# **Bonus:** segui il principio "80/20" - concentrati sui concetti che usi davvero, non su tutto ciò che esiste.

# %% [markdown]
# ### Esercizio 2 — Intermedio ★★☆
# Fai la stessa domanda 3 volte con `temperature=0` e 3 volte con `temperature=1`.
# Le risposte sono diverse? Scrivi un commento con quello che hai osservato.

# %%
# Esercizio 2 - confronto tra temperature
domandatest = "Inventa un titolo per un film di fantascienza ambientato in Sardegna."

print("temperature 0.0 3 chiamate")
for i in range(3):
    print(chiedi_claude(domandatest, temperature=0.0))
    print()

print("temperature 1.0 3 chiamate")
for i in range(3):
    print(chiedi_claude(domandatest, temperature=1.0))
    print()

# Con temperature 0.0 le risposte sono più simili.
# Con temperature 1.0 le risposte sono più creative e varie.
# Out:
# temperature 0.0 3 chiamate
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologie perdute. Potrebbe essere un film su esploratori che scoprono che la Sardegna nasconde segreti cosmici tra le sue rocce granitiche e le sue coste selvagge.
#
# Altre alternative:
# - **"Isola Temporale"** - un'isola che esiste in più dimensioni
# - **"Il Codice di Tharros"** - mistero archeologico con elementi sci-fi
# - **"Oltre il Blu di Orosei"** - avventura spaziale nelle grotte marine
#
# Quale genere di fantascienza ti piacerebbe di più?
#
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologie perdute. Potrebbe essere un film su esploratori che scoprono che la Sardegna nasconde segreti cosmici nei suoi monumenti preistorici.
#
# Altre alternative:
# - **"Isola Temporale"** - per un'avventura attraverso i buchi neri
# - **"Il Codice di Tharros"** - mistero archeologico-spaziale
# - **"Oltre il Mare di Smeraldo"** - viaggio interdimensionale
#
# Quale genere di fantascienza ti piacerebbe di più?
#
# # "Le Torri di Nuraghe"
#
# Un titolo che evoca il mistero dei nuraghi sardi, immaginando che queste antiche costruzioni siano in realtà strutture aliene o tecnologie perdute. Potrebbe essere un film su esploratori che scoprono che la Sardegna nasconde segreti cosmici nelle sue rovine preistoriche.
#
# Altre alternative:
# - **"Isola Temporale"** - un'isola che esiste in più dimensioni
# - **"Il Codice di Tharros"** - una civiltà antica con tecnologia avanzata
# - **"Oltre il Mare di Smeraldo"** - un portale interdimensionale nelle acque sarde
#
# temperature 1.0 3 chiamate
# # "Sa Biddha de Oru" - Il Portale di Pietra
#
# Un titolo che gioca con la lingua sarda e suggerisce un'atmosfera di mistero. Oppure, se preferisci qualcosa di più diretto:
#
# # "I Nuraghi del Futuro"
#
# Potrebbe raccontare di una civiltà aliena che scopre i nuraghi come antiche stazioni spaziali, o di viaggiatori temporali che cercano di proteggere i segreti nascosti nei monumenti megalitici della Sardegna.
#
# Quale tipo di storia ti intriga di più?
#
# # "Su Prantu" - Il Pianeta Rosso
#
# Un titolo che gioca sul sardo "su prantu" (il campo) e rimanda al colore rosso della terra sarda, immaginando una storia dove antichi misteri geologici dell'isola nascondono connessioni con civiltà extraterrestri.
#
# ---
#
# Altre idee:
#
# - **"Nuraghe Zero"** - strutture antiche come porte dimensionali
# - **"La Costa del Silenzio"** - misteriosi silenzi radio lungo le coste
# - **"Figli della Calada"** - (vento sardo) alieni che cavalcano i fenomeni meteorologici
#
# Qual è il genere che ti affascina di più? Potrei suggerire titoli più specifici! 🚀
#
# # "I Guardiani di Nuraghe"
#
# Un film di fantascienza che immagina antiche rovine nuragiche come stazioni di monitoraggio aliene, dove una giovane archeologa scopre che i misteriosi monumenti sardi sono in realtà parte di una rete galattica dimenticata. Ora deve decidere se rivelare la verità al mondo o proteggere il segreto che potrebbe cambiare per sempre la storia dell'umanità.
#
# Altre idee alternative:
# - **"Codice Sardus"** - thriller sci-fi su una scoperta sottomarina al largo della costa
# - **"L'Ultimo Sole di Barbagia"** - distopia ambientata in un futuro dove l'isola è diventata rifugio dell'umanità
#
# Quale genere di trama ti intriga di più?

# %% [markdown]
# ### Esercizio 3 — Intermedio ★★☆
# Crea un system prompt che fa rispondere Claude in rima. Poi chiedi qualcosa di banale.

# %%
# Esercizio 3 - system prompt in rima
systemrima = "Devi rispondere sempre in rima."
domanda = "Dimmi una breve storia in 4 righe."
risposta = chiedi_claude(domanda, temperature=0.7, system=systemrima, max_tokens=300)
print(risposta)
# Out:
# C'era una volta un gatto di città,
# Che sognava la campagna e la libertà,
# Una notte scappò verso i campi verdi,
# E trovò la felicità tra gli uccelli e i cervi.

# %% [markdown]
# ### Esercizio 4 — Avanzato ★★★ (Deliverable!)
# Crea uno script completo che:
# 1. Chiede il nome dell'utente
# 2. Usa il nome nel messaggio a Claude
# 3. Stampa la risposta in modo formattato
#
# > 💡 Su Colab usa `input()` normalmente — comparirà un campo di testo sotto la cella.

# %%
# Esercizio 4 - chatbot personalizzato
nome = input("Come ti chiami? ")
messaggio = f"Buongiorno {nome}!"

risposta = chiedi_claude(
    messaggio,
    temperature=0.0,
    system=systemrima,
    max_tokens=300
)

print("-----")
print(messaggio)
print("-----")
print(risposta)
# Out:
# Come ti chiami? Lorenzo
# -----
# Buongiorno Lorenzo!
# -----
# Buongiorno a te, che gentile saluto!
# Son Lorenzo, e son proprio qui, risoluto.
# Risponderò sempre in rima, te lo dico,
# Ogni parola sarà un verso amico.
#
# Dimmi pure cosa vuoi sapere,
# In rima bella ti saprò rispondere!
# Che sia una domanda, un dubbio, una richiesta,
# Troverai sempre una risposta in festa! 🎭

# %% [markdown]
# ---
# ## 📤 Consegna
#
# Hai completato tutti e 4 gli esercizi? Perfetto!
#
# ### Come caricare su GitHub:
#
# 1. **Scarica il notebook:**
#    `File → Scarica → Scarica .ipynb`
#
# 2. **Rinomina il file:**
#    `Lezione1_TUONOME.ipynb`
#    Es: `Lezione1_MarioRossi.ipynb`
#
# 3. **Carica su GitHub nel tuo repository personale:**
# ```bash
# # Nella cartella del tuo repo
# cp ~/Downloads/Lezione1_TUONOME.ipynb lezione1/
# git add lezione1/
# git commit -m "Lezione 1 completata"
# git push
# ```
#
# ---
#
# ### 📖 Per la prossima lezione (Giovedì 21/05)
# Leggi **Huyen Cap. 5 — Prompt Engineering** prima di venire in aula.
#
# ---
# *ITS Novitas 4.0 — AI Engineering Fundamentals | Marco Uras*
